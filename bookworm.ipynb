# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2016-11-07',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (17cb4e5d-a258-4177-aefb-42f9144ad3dd)
# {
#   "environment_id": "17cb4e5d-a258-4177-aefb-42f9144ad3dd",
#   "description": "A space to read and understand stories",
#   "read_only": false,
#   "updated": "2017-09-23T15:23:49.663Z",
#   "size": -1,
#   "created": "2017-09-23T15:23:49.663Z",
#   "name": "Bookworm",
#   "status": "active",
#   "index_capacity": {
#     "disk_usage": {
#       "used": "0 bytes",
#       "used_bytes": 0,
#       "total_bytes": 200000000,
#       "total": "200 MB",
#       "percent_used": 0.0
#     },
#     "memory_usage": {
#       "used": "N/A",
#       "used_bytes": -1,
#       "total_bytes": -1,
#       "total": "N/A",
#       "percent_used": -1.0
#     },
#     "documents": {
#       "maximum_allowed": 2000,
#       "available": 0
#     }
#   }
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
# View default configuration
cfg_id = discovery.get_default_configuration_id(environment_id=env_id)
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)
print(json.dumps(cfg, indent=2))
# Out:
# {
#   "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#   "conversions": {
#     "word": {
#       "heading": {
#         "fonts": [
#           {
#             "min_size": 24,
#             "level": 1,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "min_size": 18,
#             "max_size": 23,
#             "level": 2,
#             "bold": true,
#             "italic": false
#           },
#           {
#             "min_size": 14,
#             "max_size": 17,
#             "level": 3,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "min_size": 13,
#             "max_size": 13,
#             "level": 4,
#             "bold": true,
#             "italic": false
#           }
#         ],
#         "styles": [
#           {
#             "level": 1,
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ]
#           },
#           {
#             "level": 2,
#             "names": [
#               "subtitle"
#             ]
#           }
#         ]
#       }
#     },
#     "json_normalizations": [],
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "min_size": 24,
#             "max_size": 80,
#             "level": 1
#           },
#           {
#             "min_size": 18,
#             "max_size": 24,
#             "level": 2,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "min_size": 18,
#             "max_size": 24,
#             "level": 2,
#             "bold": true
#           },
#           {
#             "min_size": 13,
#             "max_size": 18,
#             "level": 3,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "min_size": 13,
#             "max_size": 18,
#             "level": 3,
#             "bold": true
#           },
#           {
#             "min_size": 11,
#             "max_size": 13,
#             "level": 4,
#             "bold": false,
#             "italic": false
#           }
#         ]
#       }
#     },
#     "html": {
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "keep_content": {
#         "xpaths": []
#       },
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "exclude_content": {
#         "xpaths": []
#       },
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ]
#     }
#   },
#   "updated": "2017-09-23T15:23:49.708Z",
#   "normalizations": [],
#   "configuration_id": "35ae4096-11a3-4a32-91cc-d79432130ed1",
#   "name": "Default Configuration",
#   "created": "2017-09-23T15:23:49.708Z",
#   "enrichments": [
#     {
#       "options": {
#         "sentiment": true,
#         "extract": "keyword, entity, doc-sentiment, taxonomy, concept, relation",
#         "quotations": true
#       },
#       "enrichment": "alchemy_language",
#       "destination_field": "enriched_text",
#       "source_field": "text"
#     }
#   ]
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**:

# %%
# Test configuration on some sample text
data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    res = discovery.test_document(environment_id=env_id, configuration_id=cfg_id, fileinfo=f)
print(json.dumps(res, indent=2))
# Out:
# {
#   "snapshots": [
#     {
#       "snapshot": {
#         "html": "<html>\n<head>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n</head>\n<body>\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body>"
#       },
#       "step": "html_input"
#     },
#     {
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       },
#       "step": "html_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "metadata": {},
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       },
#       "step": "json_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "metadata": {},
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       },
#       "step": "json_normalizations_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "metadata": {},
#         "enriched_text": {
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#               "relevance": 0.98887,
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#               "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#               "website": "http://www.starwars.com/movies/episode-iv"
#             },
#             {
#               "text": "Star Wars",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#               "relevance": 0.985705,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars",
#               "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#               "website": "http://www.starwars.com"
#             },
#             {
#               "text": "Rebel Alliance",
#               "relevance": 0.90639,
#               "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#               "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#               "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#             },
#             {
#               "text": "Luke Skywalker",
#               "relevance": 0.805771,
#               "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#               "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#               "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#             },
#             {
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "relevance": 0.801062,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#               "freebase": "http://rdf.freebase.com/ns/m.0f3m1",
#               "website": "http://www.starwars.com/movies/episode-v"
#             },
#             {
#               "text": "Darth Vader",
#               "relevance": 0.777337,
#               "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#               "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#               "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#             },
#             {
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "relevance": 0.77159,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddjy",
#               "website": "http://www.starwars.com/movies/episode-vi"
#             },
#             {
#               "text": "Grand Moff Tarkin",
#               "relevance": 0.748553,
#               "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#               "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#               "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#             },
#             {
#               "text": "Star Wars Episode III: Revenge of the Sith",
#               "relevance": 0.697065,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#               "freebase": "http://rdf.freebase.com/ns/m.0fdv3"
#             },
#             {
#               "text": "Princess Leia Organa",
#               "relevance": 0.607163,
#               "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#               "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa"
#             },
#             {
#               "text": "Death Star",
#               "relevance": 0.59271,
#               "dbpedia": "http://dbpedia.org/resource/Death_Star",
#               "freebase": "http://rdf.freebase.com/ns/m.0f325",
#               "yago": "http://yago-knowledge.org/resource/Death_Star"
#             },
#             {
#               "text": "Jabba the Hutt",
#               "relevance": 0.543114,
#               "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#               "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#               "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#             },
#             {
#               "text": "Galactic Empire",
#               "relevance": 0.523169,
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#             },
#             {
#               "text": "Star Wars galaxy",
#               "relevance": 0.519032,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy"
#             },
#             {
#               "text": "Star Wars Expanded Universe",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#               "relevance": 0.507885,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#               "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#               "website": "http://www.starwars.com/eu"
#             },
#             {
#               "text": "Alderaan",
#               "relevance": 0.503196,
#               "dbpedia": "http://dbpedia.org/resource/Alderaan",
#               "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#               "yago": "http://yago-knowledge.org/resource/Alderaan"
#             },
#             {
#               "text": "Carrie Fisher",
#               "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#               "relevance": 0.481464,
#               "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#               "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA"
#             },
#             {
#               "text": "Jedi",
#               "dbpedia": "http://dbpedia.org/resource/Jedi",
#               "relevance": 0.474365,
#               "yago": "http://yago-knowledge.org/resource/Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.045n4",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA"
#             },
#             {
#               "text": "The Star Wars Holiday Special",
#               "relevance": 0.4659,
#               "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#               "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#               "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#             },
#             {
#               "text": "Wedge Antilles",
#               "relevance": 0.46456,
#               "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#               "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#             },
#             {
#               "text": "English-language films",
#               "relevance": 0.460469,
#               "dbpedia": "http://dbpedia.org/resource/English-language_films"
#             },
#             {
#               "text": "Padm\u00e9 Amidala",
#               "relevance": 0.453766,
#               "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#               "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#               "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#             },
#             {
#               "text": "Galactic Civil War",
#               "relevance": 0.447243,
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#             },
#             {
#               "text": "Spaceballs",
#               "relevance": 0.436864,
#               "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#               "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#               "yago": "http://yago-knowledge.org/resource/Spaceballs"
#             },
#             {
#               "text": "Clone Wars",
#               "relevance": 0.43403,
#               "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#               "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#             },
#             {
#               "text": "C-3PO",
#               "relevance": 0.432345,
#               "dbpedia": "http://dbpedia.org/resource/C-3PO",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#               "yago": "http://yago-knowledge.org/resource/C-3PO"
#             },
#             {
#               "text": "Obi-Wan Kenobi",
#               "relevance": 0.431988,
#               "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#               "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#               "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#             },
#             {
#               "text": "R2-D2",
#               "relevance": 0.430085,
#               "dbpedia": "http://dbpedia.org/resource/R2-D2",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#               "yago": "http://yago-knowledge.org/resource/R2-D2"
#             }
#           ],
#           "keywords": [
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "sentiment": {
#                 "score": 0.447888,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "sentiment": {
#                 "score": -0.494714,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "sentiment": {
#                 "score": 0.484685,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "sentiment": {
#                 "score": 0.488854,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "sentiment": {
#                 "score": -0.494714,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "sentiment": {
#                 "score": -0.430026,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "sentiment": {
#                 "score": -0.37594,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "docSentiment": {
#             "score": -0.575489,
#             "type": "negative",
#             "mixed": false
#           },
#           "taxonomy": [
#             {
#               "score": 0.584247,
#               "confident": false,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "score": 0.517031,
#               "confident": false,
#               "label": "/society/unrest and war"
#             },
#             {
#               "confident": false,
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ],
#           "entities": [
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.972336,
#               "type": "FieldTerminology",
#               "count": 1
#             }
#           ],
#           "status": "OK",
#           "language": "english",
#           "relations": [
#             {
#               "action": {
#                 "text": "is",
#                 "lemmatized": "be",
#                 "verb": {
#                   "text": "be",
#                   "tense": "present"
#                 }
#               },
#               "subject": {
#                 "text": "It"
#               },
#               "sentence": " It is a period of civil war.",
#               "object": {
#                 "text": "a period of civil war",
#                 "sentiment": {
#                   "score": -0.564509,
#                   "type": "negative",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "civil war"
#                   },
#                   {
#                     "text": "period"
#                   }
#                 ],
#                 "entities": [
#                   {
#                     "text": "civil war",
#                     "type": "FieldTerminology"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "have won",
#                 "lemmatized": "have win",
#                 "verb": {
#                   "text": "win",
#                   "tense": "past"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spaceships, striking from a hidden base,",
#                 "keywords": [
#                   {
#                     "text": "Rebel spaceships"
#                   },
#                   {
#                     "text": "hidden base"
#                   }
#                 ]
#               },
#               "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.",
#               "object": {
#                 "text": "their first victory",
#                 "keywords": [
#                   {
#                     "text": "victory"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed",
#                 "lemmatized": "manage",
#                 "verb": {
#                   "text": "manage",
#                   "tense": "past"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "object": {
#                 "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#                 "sentiment": {
#                   "score": -0.596586,
#                   "type": "negative",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "armored space station"
#                   },
#                   {
#                     "text": "ultimate weapon"
#                   },
#                   {
#                     "text": "secret plans"
#                   },
#                   {
#                     "text": "entire planet"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed to steal",
#                 "lemmatized": "manage to steal",
#                 "verb": {
#                   "text": "steal",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "object": {
#                 "text": "secret plans",
#                 "keywords": [
#                   {
#                     "text": "secret plans"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "to destroy",
#                 "lemmatized": "to destroy",
#                 "verb": {
#                   "text": "destroy",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "object": {
#                 "text": "an entire planet",
#                 "sentiment": {
#                   "score": 0.748639,
#                   "type": "positive",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "score": -0.754579,
#                   "type": "negative",
#                   "mixed": false
#                 }
#               }
#             },
#             {
#               "action": {
#                 "text": "Pursued",
#                 "lemmatized": "Pursued",
#                 "verb": {
#                   "text": "Pursued",
#                   "tense": "past"
#                 }
#               },
#               "subject": {
#                 "text": "by the Empire",
#                 "sentiment": {
#                   "score": 0.554106,
#                   "type": "positive",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "Empire"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "object": {
#                 "text": "Princess Leia",
#                 "sentiment": {
#                   "score": 0.682563,
#                   "type": "positive",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "Princess Leia"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "can save",
#                 "lemmatized": "can save",
#                 "verb": {
#                   "text": "save",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "the stolen plans",
#                 "sentiment": {
#                   "score": -0.44097,
#                   "type": "negative",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "plans"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "object": {
#                 "text": "her people",
#                 "keywords": [
#                   {
#                     "text": "people"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "restore",
#                 "lemmatized": "restore",
#                 "verb": {
#                   "text": "restore",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "freedom",
#                 "keywords": [
#                   {
#                     "text": "freedom"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "object": {
#                 "text": "to the galaxy",
#                 "keywords": [
#                   {
#                     "text": "galaxy"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "score": 0.698799,
#                   "type": "positive",
#                   "mixed": false
#                 }
#               }
#             }
#           ]
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       },
#       "step": "enrichments_output"
#     },
#     {
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "metadata": {},
#         "enriched_text": {
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#               "relevance": 0.98887,
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#               "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#               "website": "http://www.starwars.com/movies/episode-iv"
#             },
#             {
#               "text": "Star Wars",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#               "relevance": 0.985705,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars",
#               "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#               "website": "http://www.starwars.com"
#             },
#             {
#               "text": "Rebel Alliance",
#               "relevance": 0.90639,
#               "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#               "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#               "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#             },
#             {
#               "text": "Luke Skywalker",
#               "relevance": 0.805771,
#               "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#               "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#               "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#             },
#             {
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "relevance": 0.801062,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#               "freebase": "http://rdf.freebase.com/ns/m.0f3m1",
#               "website": "http://www.starwars.com/movies/episode-v"
#             },
#             {
#               "text": "Darth Vader",
#               "relevance": 0.777337,
#               "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#               "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#               "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#             },
#             {
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "relevance": 0.77159,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddjy",
#               "website": "http://www.starwars.com/movies/episode-vi"
#             },
#             {
#               "text": "Grand Moff Tarkin",
#               "relevance": 0.748553,
#               "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#               "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#               "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#             },
#             {
#               "text": "Star Wars Episode III: Revenge of the Sith",
#               "relevance": 0.697065,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#               "freebase": "http://rdf.freebase.com/ns/m.0fdv3"
#             },
#             {
#               "text": "Princess Leia Organa",
#               "relevance": 0.607163,
#               "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#               "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa"
#             },
#             {
#               "text": "Death Star",
#               "relevance": 0.59271,
#               "dbpedia": "http://dbpedia.org/resource/Death_Star",
#               "freebase": "http://rdf.freebase.com/ns/m.0f325",
#               "yago": "http://yago-knowledge.org/resource/Death_Star"
#             },
#             {
#               "text": "Jabba the Hutt",
#               "relevance": 0.543114,
#               "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#               "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#               "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#             },
#             {
#               "text": "Galactic Empire",
#               "relevance": 0.523169,
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#             },
#             {
#               "text": "Star Wars galaxy",
#               "relevance": 0.519032,
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy"
#             },
#             {
#               "text": "Star Wars Expanded Universe",
#               "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#               "relevance": 0.507885,
#               "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#               "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#               "website": "http://www.starwars.com/eu"
#             },
#             {
#               "text": "Alderaan",
#               "relevance": 0.503196,
#               "dbpedia": "http://dbpedia.org/resource/Alderaan",
#               "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#               "yago": "http://yago-knowledge.org/resource/Alderaan"
#             },
#             {
#               "text": "Carrie Fisher",
#               "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#               "relevance": 0.481464,
#               "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#               "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA"
#             },
#             {
#               "text": "Jedi",
#               "dbpedia": "http://dbpedia.org/resource/Jedi",
#               "relevance": 0.474365,
#               "yago": "http://yago-knowledge.org/resource/Jedi",
#               "freebase": "http://rdf.freebase.com/ns/m.045n4",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA"
#             },
#             {
#               "text": "The Star Wars Holiday Special",
#               "relevance": 0.4659,
#               "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#               "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#               "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#             },
#             {
#               "text": "Wedge Antilles",
#               "relevance": 0.46456,
#               "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#               "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#               "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#             },
#             {
#               "text": "English-language films",
#               "relevance": 0.460469,
#               "dbpedia": "http://dbpedia.org/resource/English-language_films"
#             },
#             {
#               "text": "Padm\u00e9 Amidala",
#               "relevance": 0.453766,
#               "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#               "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#               "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#             },
#             {
#               "text": "Galactic Civil War",
#               "relevance": 0.447243,
#               "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#               "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#             },
#             {
#               "text": "Spaceballs",
#               "relevance": 0.436864,
#               "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#               "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#               "yago": "http://yago-knowledge.org/resource/Spaceballs"
#             },
#             {
#               "text": "Clone Wars",
#               "relevance": 0.43403,
#               "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#               "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#               "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#             },
#             {
#               "text": "C-3PO",
#               "relevance": 0.432345,
#               "dbpedia": "http://dbpedia.org/resource/C-3PO",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#               "yago": "http://yago-knowledge.org/resource/C-3PO"
#             },
#             {
#               "text": "Obi-Wan Kenobi",
#               "relevance": 0.431988,
#               "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#               "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#               "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#             },
#             {
#               "text": "R2-D2",
#               "relevance": 0.430085,
#               "dbpedia": "http://dbpedia.org/resource/R2-D2",
#               "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#               "yago": "http://yago-knowledge.org/resource/R2-D2"
#             }
#           ],
#           "keywords": [
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "sentiment": {
#                 "score": 0.447888,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "sentiment": {
#                 "score": -0.494714,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "sentiment": {
#                 "score": 0.484685,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "sentiment": {
#                 "score": 0.488854,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "sentiment": {
#                 "score": -0.494714,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "sentiment": {
#                 "score": -0.430026,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "sentiment": {
#                 "score": -0.37594,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "docSentiment": {
#             "score": -0.575489,
#             "type": "negative",
#             "mixed": false
#           },
#           "taxonomy": [
#             {
#               "score": 0.584247,
#               "confident": false,
# ...
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "sentiment": {
#                 "score": -0.494714,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "sentiment": {
#                 "score": 0.484685,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "sentiment": {
#                 "score": 0.488854,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "sentiment": {
#                 "score": -0.494714,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "sentiment": {
#                 "score": -0.430026,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "sentiment": {
#                 "score": -0.37594,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "sentiment": {
#                 "score": 0.40059,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "docSentiment": {
#             "score": -0.575489,
#             "type": "negative",
#             "mixed": false
#           },
#           "taxonomy": [
#             {
#               "score": 0.584247,
#               "confident": false,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "score": 0.517031,
#               "confident": false,
#               "label": "/society/unrest and war"
#             },
#             {
#               "confident": false,
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ],
#           "entities": [
#             {
#               "sentiment": {
#                 "score": -0.409172,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "civil war",
#               "relevance": 0.972336,
#               "type": "FieldTerminology",
#               "count": 1
#             }
#           ],
#           "status": "OK",
#           "language": "english",
#           "relations": [
#             {
#               "action": {
#                 "text": "is",
#                 "lemmatized": "be",
#                 "verb": {
#                   "text": "be",
#                   "tense": "present"
#                 }
#               },
#               "subject": {
#                 "text": "It"
#               },
#               "sentence": " It is a period of civil war.",
#               "object": {
#                 "text": "a period of civil war",
#                 "sentiment": {
#                   "score": -0.564509,
#                   "type": "negative",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "civil war"
#                   },
#                   {
#                     "text": "period"
#                   }
#                 ],
#                 "entities": [
#                   {
#                     "text": "civil war",
#                     "type": "FieldTerminology"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "have won",
#                 "lemmatized": "have win",
#                 "verb": {
#                   "text": "win",
#                   "tense": "past"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spaceships, striking from a hidden base,",
#                 "keywords": [
#                   {
#                     "text": "Rebel spaceships"
#                   },
#                   {
#                     "text": "hidden base"
#                   }
#                 ]
#               },
#               "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.",
#               "object": {
#                 "text": "their first victory",
#                 "keywords": [
#                   {
#                     "text": "victory"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed",
#                 "lemmatized": "manage",
#                 "verb": {
#                   "text": "manage",
#                   "tense": "past"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "object": {
#                 "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#                 "sentiment": {
#                   "score": -0.596586,
#                   "type": "negative",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "armored space station"
#                   },
#                   {
#                     "text": "ultimate weapon"
#                   },
#                   {
#                     "text": "secret plans"
#                   },
#                   {
#                     "text": "entire planet"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "managed to steal",
#                 "lemmatized": "manage to steal",
#                 "verb": {
#                   "text": "steal",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "object": {
#                 "text": "secret plans",
#                 "keywords": [
#                   {
#                     "text": "secret plans"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "to destroy",
#                 "lemmatized": "to destroy",
#                 "verb": {
#                   "text": "destroy",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "Rebel spies",
#                 "keywords": [
#                   {
#                     "text": "Rebel spies"
#                   }
#                 ]
#               },
#               "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#               "object": {
#                 "text": "an entire planet",
#                 "sentiment": {
#                   "score": 0.748639,
#                   "type": "positive",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "entire planet"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "score": -0.754579,
#                   "type": "negative",
#                   "mixed": false
#                 }
#               }
#             },
#             {
#               "action": {
#                 "text": "Pursued",
#                 "lemmatized": "Pursued",
#                 "verb": {
#                   "text": "Pursued",
#                   "tense": "past"
#                 }
#               },
#               "subject": {
#                 "text": "by the Empire",
#                 "sentiment": {
#                   "score": 0.554106,
#                   "type": "positive",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "Empire"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "object": {
#                 "text": "Princess Leia",
#                 "sentiment": {
#                   "score": 0.682563,
#                   "type": "positive",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "Princess Leia"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "can save",
#                 "lemmatized": "can save",
#                 "verb": {
#                   "text": "save",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "the stolen plans",
#                 "sentiment": {
#                   "score": -0.44097,
#                   "type": "negative",
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "plans"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "object": {
#                 "text": "her people",
#                 "keywords": [
#                   {
#                     "text": "people"
#                   }
#                 ]
#               }
#             },
#             {
#               "action": {
#                 "text": "restore",
#                 "lemmatized": "restore",
#                 "verb": {
#                   "text": "restore",
#                   "tense": "future"
#                 }
#               },
#               "subject": {
#                 "text": "freedom",
#                 "keywords": [
#                   {
#                     "text": "freedom"
#                   }
#                 ]
#               },
#               "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "object": {
#                 "text": "to the galaxy",
#                 "keywords": [
#                   {
#                     "text": "galaxy"
#                   }
#                 ],
#                 "sentimentFromSubject": {
#                   "score": 0.698799,
#                   "type": "positive",
#                   "mixed": false
#                 }
#               }
#             }
#           ]
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       },
#       "step": "filtering_output"
#     }
#   ],
#   "notices": [],
#   "status": "completed",
#   "original_media_type": "text/html"
# }

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "extracted_metadata": {
#     "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#   },
#   "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#   "metadata": {},
#   "enriched_text": {
#     "concepts": [
#       {
#         "text": "Star Wars Episode IV: A New Hope",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope",
#         "relevance": 0.98887,
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwVH1ipwpEbGdrcN5Y29ycA",
#         "freebase": "http://rdf.freebase.com/ns/m.0dtfn",
#         "website": "http://www.starwars.com/movies/episode-iv"
#       },
#       {
#         "text": "Star Wars",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars",
#         "relevance": 0.985705,
#         "yago": "http://yago-knowledge.org/resource/Star_Wars",
#         "freebase": "http://rdf.freebase.com/ns/m.06mmr",
#         "website": "http://www.starwars.com"
#       },
#       {
#         "text": "Rebel Alliance",
#         "relevance": 0.90639,
#         "dbpedia": "http://dbpedia.org/resource/Rebel_Alliance",
#         "freebase": "http://rdf.freebase.com/ns/m.0nr1k",
#         "yago": "http://yago-knowledge.org/resource/Rebel_Alliance"
#       },
#       {
#         "text": "Luke Skywalker",
#         "relevance": 0.805771,
#         "dbpedia": "http://dbpedia.org/resource/Luke_Skywalker",
#         "freebase": "http://rdf.freebase.com/ns/m.0f1bg",
#         "yago": "http://yago-knowledge.org/resource/Luke_Skywalker"
#       },
#       {
#         "text": "Star Wars Episode V: The Empire Strikes Back",
#         "relevance": 0.801062,
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back",
#         "freebase": "http://rdf.freebase.com/ns/m.0f3m1",
#         "website": "http://www.starwars.com/movies/episode-v"
#       },
#       {
#         "text": "Darth Vader",
#         "relevance": 0.777337,
#         "dbpedia": "http://dbpedia.org/resource/Darth_Vader",
#         "freebase": "http://rdf.freebase.com/ns/m.0f2y0",
#         "yago": "http://yago-knowledge.org/resource/Darth_Vader"
#       },
#       {
#         "text": "Star Wars Episode VI: Return of the Jedi",
#         "relevance": 0.77159,
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi",
#         "freebase": "http://rdf.freebase.com/ns/m.0ddjy",
#         "website": "http://www.starwars.com/movies/episode-vi"
#       },
#       {
#         "text": "Grand Moff Tarkin",
#         "relevance": 0.748553,
#         "dbpedia": "http://dbpedia.org/resource/Grand_Moff_Tarkin",
#         "freebase": "http://rdf.freebase.com/ns/m.0jrsz",
#         "yago": "http://yago-knowledge.org/resource/Grand_Moff_Tarkin"
#       },
#       {
#         "text": "Star Wars Episode III: Revenge of the Sith",
#         "relevance": 0.697065,
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith",
#         "freebase": "http://rdf.freebase.com/ns/m.0fdv3"
#       },
#       {
#         "text": "Princess Leia Organa",
#         "relevance": 0.607163,
#         "dbpedia": "http://dbpedia.org/resource/Princess_Leia_Organa",
#         "yago": "http://yago-knowledge.org/resource/Princess_Leia_Organa"
#       },
#       {
#         "text": "Death Star",
#         "relevance": 0.59271,
#         "dbpedia": "http://dbpedia.org/resource/Death_Star",
#         "freebase": "http://rdf.freebase.com/ns/m.0f325",
#         "yago": "http://yago-knowledge.org/resource/Death_Star"
#       },
#       {
#         "text": "Jabba the Hutt",
#         "relevance": 0.543114,
#         "dbpedia": "http://dbpedia.org/resource/Jabba_the_Hutt",
#         "freebase": "http://rdf.freebase.com/ns/m.0fjms",
#         "yago": "http://yago-knowledge.org/resource/Jabba_the_Hutt"
#       },
#       {
#         "text": "Galactic Empire",
#         "relevance": 0.523169,
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Empire_(Star_Wars)",
#         "freebase": "http://rdf.freebase.com/ns/m.0hwyg",
#         "yago": "http://yago-knowledge.org/resource/Galactic_Empire_(Star_Wars)"
#       },
#       {
#         "text": "Star Wars galaxy",
#         "relevance": 0.519032,
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_galaxy",
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_galaxy"
#       },
#       {
#         "text": "Star Wars Expanded Universe",
#         "dbpedia": "http://dbpedia.org/resource/Star_Wars_Expanded_Universe",
#         "relevance": 0.507885,
#         "yago": "http://yago-knowledge.org/resource/Star_Wars_Expanded_Universe",
#         "freebase": "http://rdf.freebase.com/ns/m.01qbrc",
#         "website": "http://www.starwars.com/eu"
#       },
#       {
#         "text": "Alderaan",
#         "relevance": 0.503196,
#         "dbpedia": "http://dbpedia.org/resource/Alderaan",
#         "freebase": "http://rdf.freebase.com/ns/m.065lhy",
#         "yago": "http://yago-knowledge.org/resource/Alderaan"
#       },
#       {
#         "text": "Carrie Fisher",
#         "dbpedia": "http://dbpedia.org/resource/Carrie_Fisher",
#         "relevance": 0.481464,
#         "yago": "http://yago-knowledge.org/resource/Carrie_Fisher",
#         "freebase": "http://rdf.freebase.com/ns/m.01tnbn",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwSJnvZwpEbGdrcN5Y29ycA"
#       },
#       {
#         "text": "Jedi",
#         "dbpedia": "http://dbpedia.org/resource/Jedi",
#         "relevance": 0.474365,
#         "yago": "http://yago-knowledge.org/resource/Jedi",
#         "freebase": "http://rdf.freebase.com/ns/m.045n4",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwNLAD5wpEbGdrcN5Y29ycA"
#       },
#       {
#         "text": "The Star Wars Holiday Special",
#         "relevance": 0.4659,
#         "dbpedia": "http://dbpedia.org/resource/The_Star_Wars_Holiday_Special",
#         "freebase": "http://rdf.freebase.com/ns/m.0199wf",
#         "yago": "http://yago-knowledge.org/resource/The_Star_Wars_Holiday_Special"
#       },
#       {
#         "text": "Wedge Antilles",
#         "relevance": 0.46456,
#         "dbpedia": "http://dbpedia.org/resource/Wedge_Antilles",
#         "freebase": "http://rdf.freebase.com/ns/m.0ddp_",
#         "yago": "http://yago-knowledge.org/resource/Wedge_Antilles"
#       },
#       {
#         "text": "English-language films",
#         "relevance": 0.460469,
#         "dbpedia": "http://dbpedia.org/resource/English-language_films"
#       },
#       {
#         "text": "Padm\u00e9 Amidala",
#         "relevance": 0.453766,
#         "dbpedia": "http://dbpedia.org/resource/Padm\u00e9_Amidala",
#         "freebase": "http://rdf.freebase.com/ns/m.0drf_",
#         "yago": "http://yago-knowledge.org/resource/Padm%C3%A9_Amidala"
#       },
#       {
#         "text": "Galactic Civil War",
#         "relevance": 0.447243,
#         "dbpedia": "http://dbpedia.org/resource/Galactic_Civil_War",
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6_",
#         "yago": "http://yago-knowledge.org/resource/Galactic_Civil_War"
#       },
#       {
#         "text": "Spaceballs",
#         "relevance": 0.436864,
#         "dbpedia": "http://dbpedia.org/resource/Spaceballs",
#         "freebase": "http://rdf.freebase.com/ns/m.0j_nw",
#         "yago": "http://yago-knowledge.org/resource/Spaceballs"
#       },
#       {
#         "text": "Clone Wars",
#         "relevance": 0.43403,
#         "dbpedia": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)",
#         "freebase": "http://rdf.freebase.com/ns/m.01qc6n",
#         "yago": "http://yago-knowledge.org/resource/Clone_Wars_(Star_Wars)"
#       },
#       {
#         "text": "C-3PO",
#         "relevance": 0.432345,
#         "dbpedia": "http://dbpedia.org/resource/C-3PO",
#         "freebase": "http://rdf.freebase.com/ns/m.0g_sv",
#         "yago": "http://yago-knowledge.org/resource/C-3PO"
#       },
#       {
#         "text": "Obi-Wan Kenobi",
#         "relevance": 0.431988,
#         "dbpedia": "http://dbpedia.org/resource/Obi-Wan_Kenobi",
#         "freebase": "http://rdf.freebase.com/ns/m.0fkm7",
#         "yago": "http://yago-knowledge.org/resource/Obi-Wan_Kenobi"
#       },
#       {
#         "text": "R2-D2",
#         "relevance": 0.430085,
#         "dbpedia": "http://dbpedia.org/resource/R2-D2",
#         "freebase": "http://rdf.freebase.com/ns/m.0g_rg",
#         "yago": "http://yago-knowledge.org/resource/R2-D2"
#       }
#     ],
#     "keywords": [
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Opening Crawl",
#         "relevance": 0.920159
#       },
#       {
#         "sentiment": {
#           "score": 0.447888,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "New Hope",
#         "relevance": 0.785031
#       },
#       {
#         "sentiment": {
#           "score": 0.40059,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "Princess Leia races",
#         "relevance": 0.775799
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Star Wars",
#         "relevance": 0.771384
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "evil Galactic Empire",
#         "relevance": 0.767527
#       },
#       {
#         "sentiment": {
#           "score": -0.494714,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "armored space station",
#         "relevance": 0.747615
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Rebel spaceships",
#         "relevance": 0.669776
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Rebel spies",
#         "relevance": 0.656828
#       },
#       {
#         "sentiment": {
#           "score": 0.484685,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "sinister agents",
#         "relevance": 0.609404
#       },
#       {
#         "sentiment": {
#           "score": -0.409172,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "civil war",
#         "relevance": 0.600682
#       },
#       {
#         "sentiment": {
#           "score": 0.488854,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "hidden base",
#         "relevance": 0.597836
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "ultimate weapon",
#         "relevance": 0.594694
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "secret plans",
#         "relevance": 0.582765
#       },
#       {
#         "sentiment": {
#           "score": -0.494714,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "entire planet",
#         "relevance": 0.582596
#       },
#       {
#         "sentiment": {
#           "score": -0.430026,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "DEATH STAR",
#         "relevance": 0.574413
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "custodian",
#         "relevance": 0.465394
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Episode",
#         "relevance": 0.462247
#       },
#       {
#         "sentiment": {
#           "score": 0.40059,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "starship",
#         "relevance": 0.443969
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "victory",
#         "relevance": 0.441799
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "galaxy",
#         "relevance": 0.437824
#       },
#       {
#         "sentiment": {
#           "score": -0.409172,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "period",
#         "relevance": 0.432092
#       },
#       {
#         "sentiment": {
#           "score": -0.37594,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "battle",
#         "relevance": 0.429238
#       },
#       {
#         "sentiment": {
#           "score": 0.40059,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "home",
#         "relevance": 0.428916
#       },
#       {
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "people",
#         "relevance": 0.428498
#       }
#     ],
#     "docSentiment": {
#       "score": -0.575489,
#       "type": "negative",
#       "mixed": false
#     },
#     "taxonomy": [
#       {
#         "score": 0.584247,
#         "confident": false,
#         "label": "/art and entertainment/movies and tv/movies"
#       },
#       {
#         "score": 0.517031,
#         "confident": false,
#         "label": "/society/unrest and war"
#       },
#       {
#         "confident": false,
#         "score": 0.215561,
#         "label": "/law, govt and politics/armed forces/army"
#       }
#     ],
#     "entities": [
#       {
#         "sentiment": {
#           "score": -0.409172,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "civil war",
#         "relevance": 0.972336,
#         "type": "FieldTerminology",
#         "count": 1
#       }
#     ],
#     "status": "OK",
#     "language": "english",
#     "relations": [
#       {
#         "action": {
#           "text": "is",
#           "lemmatized": "be",
#           "verb": {
#             "text": "be",
#             "tense": "present"
#           }
#         },
#         "subject": {
#           "text": "It"
#         },
#         "sentence": " It is a period of civil war.",
#         "object": {
#           "text": "a period of civil war",
#           "sentiment": {
#             "score": -0.564509,
#             "type": "negative",
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "civil war"
#             },
#             {
#               "text": "period"
#             }
#           ],
#           "entities": [
#             {
#               "text": "civil war",
#               "type": "FieldTerminology"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "have won",
#           "lemmatized": "have win",
#           "verb": {
#             "text": "win",
#             "tense": "past"
#           }
#         },
#         "subject": {
#           "text": "Rebel spaceships, striking from a hidden base,",
#           "keywords": [
#             {
#               "text": "Rebel spaceships"
#             },
#             {
#               "text": "hidden base"
#             }
#           ]
#         },
#         "sentence": " Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.",
#         "object": {
#           "text": "their first victory",
#           "keywords": [
#             {
#               "text": "victory"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "managed",
#           "lemmatized": "manage",
#           "verb": {
#             "text": "manage",
#             "tense": "past"
#           }
#         },
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "object": {
#           "text": "to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet",
#           "sentiment": {
#             "score": -0.596586,
#             "type": "negative",
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "armored space station"
#             },
#             {
#               "text": "ultimate weapon"
#             },
#             {
#               "text": "secret plans"
#             },
#             {
#               "text": "entire planet"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "managed to steal",
#           "lemmatized": "manage to steal",
#           "verb": {
#             "text": "steal",
#             "tense": "future"
#           }
#         },
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "object": {
#           "text": "secret plans",
#           "keywords": [
#             {
#               "text": "secret plans"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "to destroy",
#           "lemmatized": "to destroy",
#           "verb": {
#             "text": "destroy",
#             "tense": "future"
#           }
#         },
#         "subject": {
#           "text": "Rebel spies",
#           "keywords": [
#             {
#               "text": "Rebel spies"
#             }
#           ]
#         },
#         "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#         "object": {
#           "text": "an entire planet",
#           "sentiment": {
#             "score": 0.748639,
#             "type": "positive",
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "entire planet"
#             }
#           ],
#           "sentimentFromSubject": {
#             "score": -0.754579,
#             "type": "negative",
#             "mixed": false
#           }
#         }
#       },
#       {
#         "action": {
#           "text": "Pursued",
#           "lemmatized": "Pursued",
#           "verb": {
#             "text": "Pursued",
#             "tense": "past"
#           }
#         },
#         "subject": {
#           "text": "by the Empire",
#           "sentiment": {
#             "score": 0.554106,
#             "type": "positive",
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "Empire"
#             }
#           ]
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "object": {
#           "text": "Princess Leia",
#           "sentiment": {
#             "score": 0.682563,
#             "type": "positive",
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "Princess Leia"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "can save",
#           "lemmatized": "can save",
#           "verb": {
#             "text": "save",
#             "tense": "future"
#           }
#         },
#         "subject": {
#           "text": "the stolen plans",
#           "sentiment": {
#             "score": -0.44097,
#             "type": "negative",
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "plans"
#             }
#           ]
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "object": {
#           "text": "her people",
#           "keywords": [
#             {
#               "text": "people"
#             }
#           ]
#         }
#       },
#       {
#         "action": {
#           "text": "restore",
#           "lemmatized": "restore",
#           "verb": {
#             "text": "restore",
#             "tense": "future"
#           }
#         },
#         "subject": {
#           "text": "freedom",
#           "keywords": [
#             {
#               "text": "freedom"
#             }
#           ]
#         },
#         "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "object": {
#           "text": "to the galaxy",
#           "keywords": [
#             {
#               "text": "galaxy"
#             }
#           ],
#           "sentimentFromSubject": {
#             "score": 0.698799,
#             "type": "positive",
#             "mixed": false
#           }
#         }
#       }
#     ]
#   },
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**:
#
# > score: -0.575489<br/>
# > type: negative
#
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**:
#
# > 1. Star Wars Episode IV: A New Hope<br/>
# > 2. Star Wars<br/>
# > 3. Rebel Alliance
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
#
# > Actual:
#
# ```json
# {
#   "sentence": " Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#   "action": {
#     "text": "Pursued",
#     "lemmatized": "Pursued",
#     "verb": {
#       "text": "Pursued",
#       "tense": "past"
#     }
#   },
#   "object": {
#     "keywords": [
#       {
#         "text": "Princess Leia"
#       }
#     ],
#     "text": "Princess Leia",
#     "sentiment": {
#       "score": 0.682563,
#       "type": "positive",
#       "mixed": false
#     }
#   },
#   "subject": {
#     "keywords": [
#       {
#         "text": "Empire"
#       }
#     ],
#     "text": "by the Empire",
#     "sentiment": {
#       "score": 0.554106,
#       "type": "positive",
#       "mixed": false
#     }
#   }
# }
# ```
#
# > Expected:
# > - Subject should have been "Princess Leia"
# > - Object should have been "home"
#
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="white", colormap="Vega10")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
print(wc.words_)
# Out:
# {'sinister agents': 0.6622811927069125, 'evil Galactic Empire': 0.83412431981864, 'Rebel spies': 0.713820111524204, 'battle': 0.4664824231464345, 'Opening Crawl': 1.0, 'Rebel spaceships': 0.7278915926486619, 'Episode': 0.502355571156724, 'home': 0.46613248362511267, 'people': 0.46567821430861406, 'civil war': 0.6528023961076294, 'New Hope': 0.8531471191391923, 'Princess Leia races': 0.8431140705030327, 'secret plans': 0.6333307613140773, 'hidden base': 0.64970945238812, 'galaxy': 0.4758134192025509, 'entire planet': 0.6331470974038182, 'starship': 0.48249161286255965, 'armored space station': 0.8124845814690723, 'custodian': 0.5057756322548603, 'ultimate weapon': 0.6462948251334824, 'Star Wars': 0.8383159866936041, 'victory': 0.48013332478408627, 'period': 0.4695840610155419, 'DEATH STAR': 0.6242540691337041}

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Story Chunks".

# %%
# Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))
print(json.dumps(col, indent=2))
# Out:
# Created collection: Story Chunks (f2c0761c-9de6-4ee0-8a7e-10692e28900f)
# {
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "language": "en",
#   "status": "active",
#   "updated": "2017-09-23T21:20:29.309Z",
#   "collection_id": "f2c0761c-9de6-4ee0-8a7e-10692e28900f",
#   "created": "2017-09-23T21:20:29.309Z",
#   "name": "Story Chunks",
#   "configuration_id": "35ae4096-11a3-4a32-91cc-d79432130ed1"
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Story Chunks" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                file_data=json.dumps({"text": p.get_text(strip=True)}),
                mime_type="application/json",
                metadata={"title": soup.title.get_text(strip=True)})
            doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: data/Star-Wars/Episode-I_The-Phantom-Menace.html
# Adding file: data/Star-Wars/Episode-II_Attack-of-the-Clones.html
# Adding file: data/Star-Wars/Episode-III_Revenge-of-the-Sith.html
# Adding file: data/Star-Wars/Episode-IV_A-New-Hope.html
# Adding file: data/Star-Wars/Episode-V_The-Empire-Strikes-Back.html
# Adding file: data/Star-Wars/Episode-VI_Return-of-the-Jedi.html
# Adding file: data/Star-Wars/Episode-VII_The-Force-Awakens.html
# Adding file: data/Star-Wars/Rogue-One.html
# Total 42 documents added.

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (f2c0761c-9de6-4ee0-8a7e-10692e28900f)
# {
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "training_status": {
#     "processing": false,
#     "sufficient_label_diversity": false,
#     "notices": 0,
#     "minimum_queries_added": false,
#     "total_examples": 0,
#     "minimum_examples_added": false,
#     "data_updated": "",
#     "available": false,
#     "successfully_trained": ""
#   },
#   "updated": "2017-09-23T21:20:29.309Z",
#   "created": "2017-09-23T21:20:29.309Z",
#   "name": "Story Chunks",
#   "collection_id": "f2c0761c-9de6-4ee0-8a7e-10692e28900f",
#   "disk_usage": {
#     "used_bytes": 2615464
#   },
#   "configuration_id": "35ae4096-11a3-4a32-91cc-d79432130ed1",
#   "language": "en",
#   "status": "active",
#   "document_counts": {
#     "failed": 0,
#     "processing": 0,
#     "available": 42
#   }
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {'fields': [{'field': 'enriched_text.taxonomy.label', 'type': 'string'},
#   {'field': 'enriched_text.entities.sentiment.score', 'type': 'double'},
#   {'field': 'enriched_text.docSentiment.score', 'type': 'double'},
#   {'field': 'enriched_text.entities.sentiment.mixed', 'type': 'boolean'},
#   {'field': 'enriched_text.taxonomy.score', 'type': 'double'},
#   {'field': 'enriched_text.relations.object.sentimentFromSubject.type',
#    'type': 'string'},
#   {'field': 'enriched_text.entities.disambiguated.dbpedia', 'type': 'string'},
#   {'field': 'extracted_metadata.file_type', 'type': 'string'},
#   {'field': 'enriched_text.relations.location.entities', 'type': 'nested'},
#   {'field': 'enriched_text.concepts.text', 'type': 'string'},
#   {'field': 'enriched_text.docSentiment.mixed', 'type': 'boolean'},
#   {'field': 'enriched_text.relations.location', 'type': 'nested'},
#   {'field': 'enriched_text.concepts.freebase', 'type': 'string'},
#   {'field': 'enriched_text.keywords.relevance', 'type': 'double'},
#   {'field': 'enriched_text.relations.object.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.concepts.relevance', 'type': 'double'},
#   {'field': 'enriched_text.concepts.opencyc', 'type': 'string'},
#   {'field': 'enriched_text.relations.sentence', 'type': 'string'},
#   {'field': 'enriched_text.entities.disambiguated.name', 'type': 'string'},
#   {'field': 'enriched_text.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.relations.subject.entities.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.relations.subject.entities.disambiguated.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.subject.entities.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.subject.entities.type', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.entities.disambiguated.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.entities.disambiguated.freebase', 'type': 'string'},
#   {'field': 'enriched_text.relations.subject.sentiment.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.relations.subject.keywords.text', 'type': 'string'},
#   {'field': 'enriched_text.status', 'type': 'string'},
#   {'field': 'enriched_text.relations.subject.entities.disambiguated.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.relations', 'type': 'nested'},
#   {'field': 'enriched_text.relations.location.entities.disambiguated.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.subject.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.subject.entities.disambiguated.name',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.object', 'type': 'nested'},
#   {'field': 'enriched_text.relations.object.entities.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.relations.object.sentiment.score',
#    'type': 'double'},
#   {'field': 'enriched_text.relations.location.sentiment.type',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.subject.entities.disambiguated.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.docSentiment', 'type': 'nested'},
#   {'field': 'enriched_text.relations.subject', 'type': 'nested'},
#   {'field': 'enriched_text.entities.relevance', 'type': 'double'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'enriched_text.keywords.sentiment.mixed', 'type': 'boolean'},
#   {'field': 'enriched_text.entities.count', 'type': 'double'},
#   {'field': 'enriched_text.keywords.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.entities.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.relations.object.keywords.text', 'type': 'string'},
#   {'field': 'enriched_text.keywords.sentiment.type', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.entities', 'type': 'nested'},
#   {'field': 'enriched_text.concepts.ciaFactbook', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.keywords.text', 'type': 'string'},
#   {'field': 'enriched_text.entities.text', 'type': 'string'},
#   {'field': 'enriched_text.entities', 'type': 'nested'},
#   {'field': 'enriched_text.concepts.website', 'type': 'string'},
#   {'field': 'enriched_text.relations.location.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.relations.object.sentiment.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.relations.location.entities.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.relations.subject.sentiment.score',
#    'type': 'double'},
#   {'field': 'enriched_text.relations.object.sentiment.type', 'type': 'string'},
#   {'field': 'enriched_text.relations.subject.sentiment.type',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.action.verb.tense', 'type': 'string'},
#   {'field': 'enriched_text.concepts.geo', 'type': 'string'},
#   {'field': 'enriched_text.relations.location.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.entities.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.location.entities.disambiguated.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.concepts.dbpedia', 'type': 'string'},
#   {'field': 'enriched_text.taxonomy.confident', 'type': 'boolean'},
#   {'field': 'enriched_text.keywords.sentiment.score', 'type': 'double'},
#   {'field': 'enriched_text.relations.subject.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.relations.object.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.action', 'type': 'nested'},
#   {'field': 'enriched_text.relations.object.entities.type', 'type': 'string'},
#   {'field': 'enriched_text.docSentiment.type', 'type': 'string'},
#   {'field': 'enriched_text.concepts.musicBrainz', 'type': 'string'},
#   {'field': 'enriched_text.entities.type', 'type': 'string'},
#   {'field': 'extracted_metadata.sha1', 'type': 'string'},
#   {'field': 'enriched_text.relations.action.verb.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.subject.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguated.yago', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.entities.disambiguated.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.action.text', 'type': 'string'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'enriched_text.relations.object.sentimentFromSubject',
#    'type': 'nested'},
#   {'field': 'enriched_text.relations.action.verb', 'type': 'nested'},
#   {'field': 'metadata', 'type': 'nested'},
#   {'field': 'enriched_text.relations.subject.entities', 'type': 'nested'},
#   {'field': 'metadata.title', 'type': 'string'},
#   {'field': 'enriched_text.relations.location.sentiment.score',
#    'type': 'string'},
#   {'field': 'enriched_text.entities.disambiguated', 'type': 'nested'},
#   {'field': 'enriched_text.relations.location.entities.type',
#    'type': 'string'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'enriched_text.relations.location.entities.disambiguated.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.location.entities.text',
#    'type': 'string'},
#   {'field': 'enriched_text.relations.action.lemmatized', 'type': 'string'},
#   {'field': 'enriched_text.concepts.yago', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.entities.disambiguated.name',
#    'type': 'string'},
#   {'field': 'enriched_text.entities.sentiment.type', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.sentimentFromSubject.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.relations.object.entities.disambiguated.yago',
#    'type': 'string'},
#   {'field': 'extracted_metadata.filename', 'type': 'string'},
#   {'field': 'enriched_text.taxonomy', 'type': 'nested'},
#   {'field': 'enriched_text.language', 'type': 'string'},
#   {'field': 'enriched_text.relations.object.sentimentFromSubject.score',
#    'type': 'double'},
#   {'field': 'enriched_text.relations.location.entities.disambiguated.name',
#    'type': 'string'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.subject.text:\"Jar Jar\"",
        "return": "metadata.title,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 2,
#   "results": [
#     {
#       "score": 2.9906685,
#       "metadata": {
#         "title": "Star Wars: Episode I - The Phantom Menace"
#       },
#       "text": "Supreme Chancellor Valorum, leader of the Galactic Republic, dispatches Jedi Knight Qui-Gon Jinn and his apprentice, Obi-Wan Kenobi, to negotiate with the Trade Federation leadership to end a blockade of battleships around the planet Naboo. Darth Sidious, a Sith Lord and the Trade Federation's secret adviser, orders Federation Viceroy Nute Gunray to kill the Jedi and invade Naboo with an army of battle droids. The Jedi escape and flee to Naboo, where Qui-Gon saves a Gungan outcast, Jar Jar Binks, from being run over and killed by a droid tank during the invasion. Indebted to the Jedi, Jar Jar leads them to an underwater Gungan city. The Jedi unsuccessfully try to persuade the Gungan leader, Boss Nass, into helping the people of Naboo, though they are able to obtain transportation to Theed, the capital city on the surface. They rescue Queen Amidala, the ruler of the Naboo people, and escape the planet on her royal starship, which is damaged as they pass the Federation blockade.",
#       "id": "774288bf-5334-44e6-ae2f-347c65dfd291"
#     },
#     {
#       "score": 2.1361918,
#       "metadata": {
#         "title": "Star Wars: Episode I - The Phantom Menace"
#       },
#       "text": "Amidala's ship is unable to sustain its hyperdrive and lands for repairs on the desert planet Tatooine. Qui-Gon, Jar Jar, astromech droid R2-D2, and Amidala (in disguise as the handmaiden Padm\u00e9) visit the settlement of Mos Espa to buy new parts at a junk shop. They meet the shop's owner Watto and his nine-year-old slave, Anakin Skywalker, who is a gifted pilot and engineer and has created a protocol droid called C-3PO. Qui-Gon senses a strong presence of the Force within Anakin and is convinced that he is the \"chosen one\" of Jedi prophecy who will bring balance to the Force. Qui-Gon wagers Anakin's freedom with Watto in a Podrace, which Anakin wins. Anakin joins the group to be trained as a Jedi, leaving his mother Shmi behind. En route to their starship, Qui-Gon briefly duels with Darth Maul, Darth Sidious's apprentice, who was sent to capture Amidala. Qui-Gon quits the duel and escapes by leaping onto the open boarding ramp of the departing starship.",
#       "id": "d894ef86-edfb-42fb-9d9a-37ce5a0f3b71"
#     }
#   ]
# }

# %%
# Another query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.object.sentimentFromSubject.type::positive",
        "return": "metadata.title,enriched_text.relations.sentence"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 38,
#   "results": [
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode I - The Phantom Menace"
#       },
#       "id": "b8b60acd-1ebf-4f07-9a7d-8f7a34662d76",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "On Naboo, Padm\u00e9 reveals herself to the Gungans as Queen Amidala and persuades them into an alliance against the Trade Federation."
#           },
#           {
#             "sentence": "On Naboo, Padm\u00e9 reveals herself to the Gungans as Queen Amidala and persuades them into an alliance against the Trade Federation."
#           },
#           {
#             "sentence": " Jar Jar leads his people in a battle against the droid army while Padm\u00e9 leads the hunt for Gunray in Theed."
#           },
#           {
#             "sentence": " During a battle in a starship hangar to free Naboo pilots, Anakin takes shelter in a vacant starfighter and inadvertently triggers its autopilot, joining the battle against the Federation droid control ship in space."
#           },
#           {
#             "sentence": " During a battle in a starship hangar to free Naboo pilots, Anakin takes shelter in a vacant starfighter and inadvertently triggers its autopilot, joining the battle against the Federation droid control ship in space."
#           },
#           {
#             "sentence": " During a battle in a starship hangar to free Naboo pilots, Anakin takes shelter in a vacant starfighter and inadvertently triggers its autopilot, joining the battle against the Federation droid control ship in space."
#           },
#           {
#             "sentence": " During a battle in a starship hangar to free Naboo pilots, Anakin takes shelter in a vacant starfighter and inadvertently triggers its autopilot, joining the battle against the Federation droid control ship in space."
#           },
#           {
#             "sentence": " Anakin blunders into the hangar of the droid control ship and destroys the ship from within before escaping, deactivating the droid army."
#           },
#           {
#             "sentence": " Anakin blunders into the hangar of the droid control ship and destroys the ship from within before escaping, deactivating the droid army."
#           },
#           {
#             "sentence": " Meanwhile, Qui-Gon and Obi-Wan battle Darth Maul, who mortally wounds Qui-Gon before being bisected by Obi-Wan."
#           },
#           {
#             "sentence": " Meanwhile, Qui-Gon and Obi-Wan battle Darth Maul, who mortally wounds Qui-Gon before being bisected by Obi-Wan."
#           },
#           {
#             "sentence": " As he dies, Qui-Gon asks Obi-Wan to train Anakin."
#           },
#           {
#             "sentence": " Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray is arrested."
#           },
#           {
#             "sentence": " Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray is arrested."
#           },
#           {
#             "sentence": " Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray is arrested."
#           },
#           {
#             "sentence": " Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray is arrested."
#           },
#           {
#             "sentence": " The Jedi Council promotes Obi-Wan to the rank of Jedi Knight and reluctantly accepts Anakin as Obi-Wan's apprentice."
#           },
#           {
#             "sentence": " The Jedi Council promotes Obi-Wan to the rank of Jedi Knight and reluctantly accepts Anakin as Obi-Wan's apprentice."
#           },
#           {
#             "sentence": " At a festive ceremony, Padm\u00e9 presents a gift of appreciation and friendship to the Gungans."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode II - Attack of the Clones"
#       },
#       "id": "39766a63-9fa3-4720-a65d-34c2bb46e36a",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "Ten years after the Trade Federation's invasion of Naboo, the Galactic Republic is threatened by a Separatist movement organized by former Jedi Master Count Dooku."
#           },
#           {
#             "sentence": "Ten years after the Trade Federation's invasion of Naboo, the Galactic Republic is threatened by a Separatist movement organized by former Jedi Master Count Dooku."
#           },
#           {
#             "sentence": "Ten years after the Trade Federation's invasion of Naboo, the Galactic Republic is threatened by a Separatist movement organized by former Jedi Master Count Dooku."
#           },
#           {
#             "sentence": " Senator Padm\u00e9 Amidala comes to Coruscant to vote on a motion to create an army to assist the Jedi against this threat."
#           },
#           {
#             "sentence": " Narrowly avoiding an assassination attempt upon arrival, she is placed under the protection of Jedi Knight Obi-Wan Kenobi and his apprentice, Anakin Skywalker."
#           },
#           {
#             "sentence": " The two Jedi thwart a second attempt on her life and subdue the assassin, Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client before she can reveal his identity."
#           },
#           {
#             "sentence": " The two Jedi thwart a second attempt on her life and subdue the assassin, Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client before she can reveal his identity."
#           },
#           {
#             "sentence": " The two Jedi thwart a second attempt on her life and subdue the assassin, Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client before she can reveal his identity."
#           },
#           {
#             "sentence": " The two Jedi thwart a second attempt on her life and subdue the assassin, Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client before she can reveal his identity."
#           },
#           {
#             "sentence": " The two Jedi thwart a second attempt on her life and subdue the assassin, Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client before she can reveal his identity."
#           },
#           {
#             "sentence": " The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, while Anakin is assigned to escort Padm\u00e9 back to Naboo, where the pair develop a romantic attraction towards each other."
#           },
#           {
#             "sentence": " The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, while Anakin is assigned to escort Padm\u00e9 back to Naboo, where the pair develop a romantic attraction towards each other."
#           },
#           {
#             "sentence": " The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, while Anakin is assigned to escort Padm\u00e9 back to Naboo, where the pair develop a romantic attraction towards each other."
#           },
#           {
#             "sentence": " The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, while Anakin is assigned to escort Padm\u00e9 back to Naboo, where the pair develop a romantic attraction towards each other."
#           },
#           {
#             "sentence": " The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, while Anakin is assigned to escort Padm\u00e9 back to Naboo, where the pair develop a romantic attraction towards each other."
#           },
#           {
#             "sentence": " The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, while Anakin is assigned to escort Padm\u00e9 back to Naboo, where the pair develop a romantic attraction towards each other."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode II - Attack of the Clones"
#       },
#       "id": "dea55f0d-921b-4652-93c6-d589c092df71",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "Obi-Wan's investigation leads him to the remote ocean planet Kamino, where he discovers an army of clones is being produced for the Republic, with bounty hunter Jango Fett serving as their genetic template."
#           },
#           {
#             "sentence": "Obi-Wan's investigation leads him to the remote ocean planet Kamino, where he discovers an army of clones is being produced for the Republic, with bounty hunter Jango Fett serving as their genetic template."
#           },
#           {
#             "sentence": " Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows him and his clone son, Boba, to the desert planet Geonosis via a homing beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled by premonitions of his mother, Shmi, in pain, and travels to Tatooine with Padm\u00e9 to save her."
#           },
#           {
#             "sentence": " Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows him and his clone son, Boba, to the desert planet Geonosis via a homing beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled by premonitions of his mother, Shmi, in pain, and travels to Tatooine with Padm\u00e9 to save her."
#           },
#           {
#             "sentence": " Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows him and his clone son, Boba, to the desert planet Geonosis via a homing beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled by premonitions of his mother, Shmi, in pain, and travels to Tatooine with Padm\u00e9 to save her."
#           },
#           {
#             "sentence": " They meet Owen Lars, Anakin's stepbrother and the son of Shmi's new husband, Cliegg Lars."
#           },
#           {
#             "sentence": " Cliegg tells Anakin that Shmi was abducted by Tusken Raiders weeks earlier and is likely dead."
#           },
#           {
#             "sentence": " Determined to find her, Anakin ventures out and finds Shmi at the Tusken campsite, where she dies in Anakin's arms."
#           },
#           {
#             "sentence": " Determined to find her, Anakin ventures out and finds Shmi at the Tusken campsite, where she dies in Anakin's arms."
#           },
#           {
#             "sentence": " Enraged, Anakin massacres the Tuskens and returns to the Lars homestead with Shmi's body."
#           },
#           {
#             "sentence": " After revealing his deed to Padm\u00e9, Anakin says that he wants to prevent death."
#           },
#           {
#             "sentence": " After revealing his deed to Padm\u00e9, Anakin says that he wants to prevent death."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode II - Attack of the Clones"
#       },
#       "id": "b49bfcba-2953-485c-a95c-a246d61406cf",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00e9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray."
#           },
#           {
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00e9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray."
#           },
#           {
#             "sentence": "On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, whom Obi-Wan learns had authorized Padm\u00e9's assassination and is developing a battle droid army with Trade Federation Viceroy Nute Gunray."
#           },
#           {
#             "sentence": " With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle."
#           },
#           {
#             "sentence": " With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle."
#           },
#           {
#             "sentence": " With knowledge of the droid army, Supreme Chancellor Palpatine is voted emergency powers to send the clones into battle."
#           },
#           {
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue."
#           },
#           {
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue."
#           },
#           {
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue."
#           },
#           {
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue."
#           },
#           {
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue."
#           },
#           {
#             "sentence": " The three are sentenced to death, but are eventually saved by a battalion of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed by Mace during the rescue."
#           },
#           {
#             "sentence": " Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he delivers blueprints for a superweapon to his Sith master, Darth Sidious."
#           },
#           {
#             "sentence": " Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he delivers blueprints for a superweapon to his Sith master, Darth Sidious."
#           },
#           {
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00e9 on Naboo, with C-3PO and R2-D2 as their witnesses."
#           },
#           {
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00e9 on Naboo, with C-3PO and R2-D2 as their witnesses."
#           },
#           {
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00e9 on Naboo, with C-3PO and R2-D2 as their witnesses."
#           },
#           {
#             "sentence": " As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is fitted with a robotic arm and secretly marries Padm\u00e9 on Naboo, with C-3PO and R2-D2 as their witnesses."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "id": "8c52f435-f324-491f-9c36-7640ab3fe843",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "Three years after the the start of the Clone Wars between the Galactic Republic and the Confederacy of Independent Systems, war has gripped the galaxy."
#           },
#           {
#             "sentence": "Three years after the the start of the Clone Wars between the Galactic Republic and the Confederacy of Independent Systems, war has gripped the galaxy."
#           },
#           {
#             "sentence": " During a space battle over the planet Coruscant, Jedi Knights Obi-Wan Kenobi and Anakin Skywalker lead a mission to rescue the kidnapped Supreme Chancellor Palpatine from Separatist commander General Grievous."
#           },
#           {
#             "sentence": " After infiltrating Grievous's flagship, the Jedi battle Count Dooku."
#           },
#           {
#             "sentence": " Anakin subdues Dooku, and on Palpatine's urging, executes him."
#           },
#           {
#             "sentence": " There, Anakin reunites with his wife, Padm\u00e9 Amidala, who reveals she is pregnant."
#           },
#           {
#             "sentence": " While initially excited, Anakin begins to have prophetic visions of Padm\u00e9 dying in childbirth, and his worry steadily grows."
#           },
#           {
#             "sentence": " While initially excited, Anakin begins to have prophetic visions of Padm\u00e9 dying in childbirth, and his worry steadily grows."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode IV - A New Hope"
#       },
#       "id": "a8ebe066-9dab-4461-884d-6b385efafa21",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis."
#           },
#           {
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis."
#           },
#           {
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis."
#           },
#           {
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis."
#           },
#           {
#             "sentence": " Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the Force."
#           },
#           {
#             "sentence": " Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the Force."
#           },
#           {
#             "sentence": " Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle."
#           },
#           {
#             "sentence": " Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle."
#           },
#           {
#             "sentence": " Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle."
#           },
#           {
#             "sentence": " Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle."
#           },
#           {
#             "sentence": " Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon."
#           },
#           {
#             "sentence": " Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode IV - A New Hope"
#       },
#       "id": "fd9b4913-e534-405f-8b15-6cecbf8614c7",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker."
#           },
#           {
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker."
#           },
#           {
#             "sentence": " While cleaning R2-D2, Luke accidentally triggers part of Leia's message, in which she requests help from Obi-Wan Kenobi."
#           },
#           {
#             "sentence": " While cleaning R2-D2, Luke accidentally triggers part of Leia's message, in which she requests help from Obi-Wan Kenobi."
#           },
#           {
#             "sentence": " The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben Kenobi, an old hermit who lives in the hills and reveals himself to be Obi-Wan."
#           },
#           {
#             "sentence": " The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben Kenobi, an old hermit who lives in the hills and reveals himself to be Obi-Wan."
#           },
#           {
#             "sentence": " The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben Kenobi, an old hermit who lives in the hills and reveals himself to be Obi-Wan."
#           },
#           {
#             "sentence": " The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben Kenobi, an old hermit who lives in the hills and reveals himself to be Obi-Wan."
#           },
#           {
#             "sentence": " Obi-Wan tells Luke of his days as one of the Jedi Knights, former Galactic Republic peacekeepers with supernatural powers derived from an energy called The Force, who were all but wiped out by the Empire."
#           },
#           {
#             "sentence": " Contrary to his uncle's statements, Luke learns that his father, Anakin, fought alongside Obi-Wan as a Jedi Knight."
#           },
#           {
#             "sentence": " Contrary to his uncle's statements, Luke learns that his father, Anakin, fought alongside Obi-Wan as a Jedi Knight."
#           },
#           {
#             "sentence": " Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin."
#           },
#           {
#             "sentence": " Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin."
#           },
#           {
#             "sentence": " Obi-Wan then presents to Luke his father's weapon \u2013 a lightsaber."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode IV - A New Hope"
#       },
#       "id": "f3b3db80-2137-4bf5-a819-5b8eacba3176",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "Upon the Falcon's arrival at the location of Alderaan, the group discover that the planet has been destroyed by order of the Death Star's commanding officer, Grand Moff Tarkin, as a show of power."
#           },
#           {
#             "sentence": " The Falcon is captured by the Death Star's tractor beam and brought into its hangar bay."
#           },
#           {
#             "sentence": " The Falcon is captured by the Death Star's tractor beam and brought into its hangar bay."
#           },
#           {
#             "sentence": " While Obi-Wan goes to disable the tractor beam, Luke discovers that Leia is imprisoned aboard, and with the help of Han and Chewbacca, rescues her."
#           },
#           {
#             "sentence": " While Obi-Wan goes to disable the tractor beam, Luke discovers that Leia is imprisoned aboard, and with the help of Han and Chewbacca, rescues her."
#           },
#           {
#             "sentence": " While Obi-Wan goes to disable the tractor beam, Luke discovers that Leia is imprisoned aboard, and with the help of Han and Chewbacca, rescues her."
#           },
#           {
#             "sentence": " After several escapes, the group makes its way back to the Falcon."
#           },
#           {
#             "sentence": " Once he is sure the others can escape, Obi-Wan allows himself to be killed."
#           },
#           {
#             "sentence": " The Falcon escapes from the Death Star, unknowingly carrying a tracking beacon, which the Empire follows to the Rebels' hidden base on Yavin IV."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "id": "420a95c7-2528-4220-8d7e-f44011091d49",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire."
#           },
#           {
#             "sentence": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire."
#           },
#           {
#             "sentence": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire."
#           },
#           {
#             "sentence": " The Rebels, led by Princess Leia, have set up their new base on the ice planet Hoth."
#           },
#           {
#             "sentence": " The Rebels, led by Princess Leia, have set up their new base on the ice planet Hoth."
#           },
#           {
#             "sentence": " The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy."
#           },
#           {
#             "sentence": " The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy."
#           },
#           {
#             "sentence": " The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy."
#           }
#         ]
#       }
#     },
#     {
#       "score": 3.8940988,
#       "metadata": {
#         "title": "Star Wars: Episode IV - A New Hope"
#       },
#       "id": "e5b2a823-1dd9-40d2-8418-6bba2a416670",
#       "enriched_text": {
#         "relations": [
#           {
#             "sentence": "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust port that connects to the station's main reactor."
#           },
#           {
#             "sentence": "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust port that connects to the station's main reactor."
#           },
#           {
#             "sentence": "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust port that connects to the station's main reactor."
#           },
#           {
#             "sentence": " Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help."
#           },
#           {
#             "sentence": " Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help."
#           },
#           {
#             "sentence": " Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help."
#           },
#           {
#             "sentence": " In the ensuing battle, the Rebels suffer heavy losses after several unsuccessful attack runs, leaving Luke as one of the few surviving pilots."
#           },
#           {
#             "sentence": " In the ensuing battle, the Rebels suffer heavy losses after several unsuccessful attack runs, leaving Luke as one of the few surviving pilots."
#           },
#           {
#             "sentence": " Vader leads a squadron of TIE fighters and prepares to attack Luke's X-wing fighter, but Han returns and fires on the Imperials, sending Vader spiraling away."
#           },
#           {
#             "sentence": " Vader leads a squadron of TIE fighters and prepares to attack Luke's X-wing fighter, but Han returns and fires on the Imperials, sending Vader spiraling away."
#           },
#           {
#             "sentence": " Helped by guidance from Obi-Wan's spirit, Luke uses the Force and successfully destroys the Death Star seconds before it can fire on the Rebel base."
#           },
#           {
#             "sentence": " Helped by guidance from Obi-Wan's spirit, Luke uses the Force and successfully destroys the Death Star seconds before it can fire on the Rebel base."
#           },
#           {
#             "sentence": " Helped by guidance from Obi-Wan's spirit, Luke uses the Force and successfully destroys the Death Star seconds before it can fire on the Rebel base."
#           },
#           {
#             "sentence": " Back on Yavin IV, Leia awards Luke and Han with medals for their heroism."
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
# print([[rels for rels in r['enriched_text']['relations']] for r in results['results']])
from pprint import pprint
pos_sentences = set()
for r in results['results']:
    for rels in r['enriched_text']['relations']:
        pos_sentences.add(rels['sentence'])
print('Total positive sentences:', len(pos_sentences))
pprint(pos_sentences)
# Out:
# Total positive sentences: 58
# {" After infiltrating Grievous's flagship, the Jedi battle Count Dooku.",
#  ' After revealing his deed to Padmé, Anakin says that he wants to prevent '
#  'death.',
#  ' After several escapes, the group makes its way back to the Falcon.',
#  ' Anakin blunders into the hangar of the droid control ship and destroys the '
#  'ship from within before escaping, deactivating the droid army.',
#  " Anakin subdues Dooku, and on Palpatine's urging, executes him.",
#  ' As he dies, Qui-Gon asks Obi-Wan to train Anakin.',
#  ' As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is '
#  'fitted with a robotic arm and secretly marries Padmé on Naboo, with C-3PO '
#  'and R2-D2 as their witnesses.',
#  ' At a festive ceremony, Padmé presents a gift of appreciation and friendship '
#  'to the Gungans.',
#  ' Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.',
#  ' Cliegg tells Anakin that Shmi was abducted by Tusken Raiders weeks earlier '
#  'and is likely dead.',
#  " Contrary to his uncle's statements, Luke learns that his father, Anakin, "
#  'fought alongside Obi-Wan as a Jedi Knight.',
#  ' Determined to find her, Anakin ventures out and finds Shmi at the Tusken '
#  "campsite, where she dies in Anakin's arms.",
#  ' During a battle in a starship hangar to free Naboo pilots, Anakin takes '
#  'shelter in a vacant starfighter and inadvertently triggers its autopilot, '
#  'joining the battle against the Federation droid control ship in space.',
#  ' During a space battle over the planet Coruscant, Jedi Knights Obi-Wan '
#  'Kenobi and Anakin Skywalker lead a mission to rescue the kidnapped Supreme '
#  'Chancellor Palpatine from Separatist commander General Grievous.',
#  ' Enraged, Anakin massacres the Tuskens and returns to the Lars homestead '
#  "with Shmi's body.",
#  ' Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he '
#  'delivers blueprints for a superweapon to his Sith master, Darth Sidious.',
#  " Helped by guidance from Obi-Wan's spirit, Luke uses the Force and "
#  'successfully destroys the Death Star seconds before it can fire on the Rebel '
#  'base.',
#  ' In the ensuing battle, the Rebels suffer heavy losses after several '
#  'unsuccessful attack runs, leaving Luke as one of the few surviving pilots.',
#  ' Jar Jar leads his people in a battle against the droid army while Padmé '
#  'leads the hunt for Gunray in Theed.',
#  ' Luke declines, but changes his mind after discovering that Imperial '
#  'stormtroopers searching for C-3PO and R2-D2 have destroyed his home and '
#  'killed his aunt and uncle.',
#  ' Luke joins the Rebel assault squadron, while Han collects his payment for '
#  "the transport and intends to leave, despite Luke's request that he stay and "
#  'help.',
#  ' Meanwhile, Qui-Gon and Obi-Wan battle Darth Maul, who mortally wounds '
#  'Qui-Gon before being bisected by Obi-Wan.',
#  ' Narrowly avoiding an assassination attempt upon arrival, she is placed '
#  'under the protection of Jedi Knight Obi-Wan Kenobi and his apprentice, '
#  'Anakin Skywalker.',
#  ' Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate '
#  "Chewbacca to transport them to Alderaan on Han's ship, the Millennium "
#  'Falcon.',
#  ' Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows '
#  'him and his clone son, Boba, to the desert planet Geonosis via a homing '
#  'beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled '
#  'by premonitions of his mother, Shmi, in pain, and travels to Tatooine with '
#  'Padmé to save her.',
#  ' Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the '
#  'Force.',
#  ' Obi-Wan tells Luke of his days as one of the Jedi Knights, former Galactic '
#  'Republic peacekeepers with supernatural powers derived from an energy called '
#  'The Force, who were all but wiped out by the Empire.',
#  ' Obi-Wan tells Luke that Vader was his former pupil who turned to the dark '
#  'side of the Force and killed Anakin.',
#  " Obi-Wan then presents to Luke his father's weapon – a lightsaber.",
#  ' Once he is sure the others can escape, Obi-Wan allows himself to be killed.',
#  ' Senator Padmé Amidala comes to Coruscant to vote on a motion to create an '
#  'army to assist the Jedi against this threat.',
#  ' Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray '
#  'is arrested.',
#  ' The Falcon escapes from the Death Star, unknowingly carrying a tracking '
#  "beacon, which the Empire follows to the Rebels' hidden base on Yavin IV.",
#  " The Falcon is captured by the Death Star's tractor beam and brought into "
#  'its hangar bay.',
#  ' The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels’ '
#  'new base by dispatching probe droids across the galaxy.',
#  ' The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, '
#  'while Anakin is assigned to escort Padmé back to Naboo, where the pair '
#  'develop a romantic attraction towards each other.',
#  ' The Jedi Council promotes Obi-Wan to the rank of Jedi Knight and '
#  "reluctantly accepts Anakin as Obi-Wan's apprentice.",
#  ' The Rebels, led by Princess Leia, have set up their new base on the ice '
#  'planet Hoth.',
#  ' The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben '
#  'Kenobi, an old hermit who lives in the hills and reveals himself to be '
#  'Obi-Wan.',
#  ' The three are sentenced to death, but are eventually saved by a battalion '
#  'of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed '
#  'by Mace during the rescue.',
#  ' The two Jedi thwart a second attempt on her life and subdue the assassin, '
#  'Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client '
#  'before she can reveal his identity.',
#  ' There, Anakin reunites with his wife, Padmé Amidala, who reveals she is '
#  'pregnant.',
#  " They meet Owen Lars, Anakin's stepbrother and the son of Shmi's new "
#  'husband, Cliegg Lars.',
#  " Vader leads a squadron of TIE fighters and prepares to attack Luke's X-wing "
#  'fighter, but Han returns and fires on the Imperials, sending Vader spiraling '
#  'away.',
#  ' While Obi-Wan goes to disable the tractor beam, Luke discovers that Leia is '
#  'imprisoned aboard, and with the help of Han and Chewbacca, rescues her.',
#  " While cleaning R2-D2, Luke accidentally triggers part of Leia's message, in "
#  'which she requests help from Obi-Wan Kenobi.',
#  ' While initially excited, Anakin begins to have prophetic visions of Padmé '
#  'dying in childbirth, and his worry steadily grows.',
#  ' With knowledge of the droid army, Supreme Chancellor Palpatine is voted '
#  'emergency powers to send the clones into battle.',
#  "Obi-Wan views Leia's complete message, in which she begs him to take the "
#  'Death Star plans to her home planet of Alderaan and give them to her father '
#  'for analysis.',
#  "Obi-Wan's investigation leads him to the remote ocean planet Kamino, where "
#  'he discovers an army of clones is being produced for the Republic, with '
#  'bounty hunter Jango Fett serving as their genetic template.',
#  'On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, '
#  "whom Obi-Wan learns had authorized Padmé's assassination and is developing a "
#  'battle droid army with Trade Federation Viceroy Nute Gunray.',
#  'On Naboo, Padmé reveals herself to the Gungans as Queen Amidala and '
#  'persuades them into an alliance against the Trade Federation.',
#  "Ten years after the Trade Federation's invasion of Naboo, the Galactic "
#  'Republic is threatened by a Separatist movement organized by former Jedi '
#  'Master Count Dooku.',
#  "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust "
#  "port that connects to the station's main reactor.",
#  'The droids are captured by Jawa traders, who sell them to moisture farmers '
#  'Owen and Beru Lars and their nephew Luke Skywalker.',
#  'Three years after the destruction of the Death Star, the Rebel Alliance has '
#  'been driven from their former base on Yavin IV by the Galactic Empire.',
#  'Three years after the the start of the Clone Wars between the Galactic '
#  'Republic and the Confederacy of Independent Systems, war has gripped the '
#  'galaxy.',
#  "Upon the Falcon's arrival at the location of Alderaan, the group discover "
#  "that the planet has been destroyed by order of the Death Star's commanding "
#  'officer, Grand Moff Tarkin, as a show of power.'}

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**:
#
# > Show me all the sentences with keywords with a positive `sentimentFromSubject`.
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text from the paragraph(s) returned.
#
# **A**:
#
# ```
# Total positive sentences: 58
# {" After infiltrating Grievous's flagship, the Jedi battle Count Dooku.",
#  ' After revealing his deed to Padmé, Anakin says that he wants to prevent '
#  'death.',
#  ' After several escapes, the group makes its way back to the Falcon.',
#  ' Anakin blunders into the hangar of the droid control ship and destroys the '
#  'ship from within before escaping, deactivating the droid army.',
#  " Anakin subdues Dooku, and on Palpatine's urging, executes him.",
#  ' As he dies, Qui-Gon asks Obi-Wan to train Anakin.',
#  ' As the Jedi gravely acknowledge the beginning of the Clone Wars, Anakin is '
#  'fitted with a robotic arm and secretly marries Padmé on Naboo, with C-3PO '
#  'and R2-D2 as their witnesses.',
#  ' At a festive ceremony, Padmé presents a gift of appreciation and friendship '
#  'to the Gungans.',
#  ' Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.',
#  ' Cliegg tells Anakin that Shmi was abducted by Tusken Raiders weeks earlier '
#  'and is likely dead.',
#  " Contrary to his uncle's statements, Luke learns that his father, Anakin, "
#  'fought alongside Obi-Wan as a Jedi Knight.',
#  ' Determined to find her, Anakin ventures out and finds Shmi at the Tusken '
#  "campsite, where she dies in Anakin's arms.",
#  ' During a battle in a starship hangar to free Naboo pilots, Anakin takes '
#  'shelter in a vacant starfighter and inadvertently triggers its autopilot, '
#  'joining the battle against the Federation droid control ship in space.',
#  ' During a space battle over the planet Coruscant, Jedi Knights Obi-Wan '
#  'Kenobi and Anakin Skywalker lead a mission to rescue the kidnapped Supreme '
#  'Chancellor Palpatine from Separatist commander General Grievous.',
#  ' Enraged, Anakin massacres the Tuskens and returns to the Lars homestead '
#  "with Shmi's body.",
#  ' Finding he is unable to defeat Yoda, Dooku flees to Coruscant, where he '
#  'delivers blueprints for a superweapon to his Sith master, Darth Sidious.',
#  " Helped by guidance from Obi-Wan's spirit, Luke uses the Force and "
#  'successfully destroys the Death Star seconds before it can fire on the Rebel '
#  'base.',
#  ' In the ensuing battle, the Rebels suffer heavy losses after several '
#  'unsuccessful attack runs, leaving Luke as one of the few surviving pilots.',
#  ' Jar Jar leads his people in a battle against the droid army while Padmé '
#  'leads the hunt for Gunray in Theed.',
#  ' Luke declines, but changes his mind after discovering that Imperial '
#  'stormtroopers searching for C-3PO and R2-D2 have destroyed his home and '
#  'killed his aunt and uncle.',
#  ' Luke joins the Rebel assault squadron, while Han collects his payment for '
#  "the transport and intends to leave, despite Luke's request that he stay and "
#  'help.',
#  ' Meanwhile, Qui-Gon and Obi-Wan battle Darth Maul, who mortally wounds '
#  'Qui-Gon before being bisected by Obi-Wan.',
#  ' Narrowly avoiding an assassination attempt upon arrival, she is placed '
#  'under the protection of Jedi Knight Obi-Wan Kenobi and his apprentice, '
#  'Anakin Skywalker.',
#  ' Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate '
#  "Chewbacca to transport them to Alderaan on Han's ship, the Millennium "
#  'Falcon.',
#  ' Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows '
#  'him and his clone son, Boba, to the desert planet Geonosis via a homing '
#  'beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled '
#  'by premonitions of his mother, Shmi, in pain, and travels to Tatooine with '
#  'Padmé to save her.',
#  ' Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the '
#  'Force.',
#  ' Obi-Wan tells Luke of his days as one of the Jedi Knights, former Galactic '
#  'Republic peacekeepers with supernatural powers derived from an energy called '
#  'The Force, who were all but wiped out by the Empire.',
#  ' Obi-Wan tells Luke that Vader was his former pupil who turned to the dark '
#  'side of the Force and killed Anakin.',
#  " Obi-Wan then presents to Luke his father's weapon – a lightsaber.",
#  ' Once he is sure the others can escape, Obi-Wan allows himself to be killed.',
#  ' Senator Padmé Amidala comes to Coruscant to vote on a motion to create an '
#  'army to assist the Jedi against this threat.',
#  ' Subsequently, Palpatine is elected as the new Supreme Chancellor and Gunray '
#  'is arrested.',
#  ' The Falcon escapes from the Death Star, unknowingly carrying a tracking '
#  "beacon, which the Empire follows to the Rebels' hidden base on Yavin IV.",
#  " The Falcon is captured by the Death Star's tractor beam and brought into "
#  'its hangar bay.',
#  ' The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels’ '
#  'new base by dispatching probe droids across the galaxy.',
#  ' The Jedi Council assigns Obi-Wan to identify and capture the bounty hunter, '
#  'while Anakin is assigned to escort Padmé back to Naboo, where the pair '
#  'develop a romantic attraction towards each other.',
#  ' The Jedi Council promotes Obi-Wan to the rank of Jedi Knight and '
#  "reluctantly accepts Anakin as Obi-Wan's apprentice.",
#  ' The Rebels, led by Princess Leia, have set up their new base on the ice '
#  'planet Hoth.',
#  ' The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben '
#  'Kenobi, an old hermit who lives in the hills and reveals himself to be '
#  'Obi-Wan.',
#  ' The three are sentenced to death, but are eventually saved by a battalion '
#  'of Jedi and clone troopers led by Mace Windu and Yoda; Jango Fett is killed '
#  'by Mace during the rescue.',
#  ' The two Jedi thwart a second attempt on her life and subdue the assassin, '
#  'Zam Wesell, a shape-shifter who is soon killed by her bounty hunter client '
#  'before she can reveal his identity.',
#  ' There, Anakin reunites with his wife, Padmé Amidala, who reveals she is '
#  'pregnant.',
#  " They meet Owen Lars, Anakin's stepbrother and the son of Shmi's new "
#  'husband, Cliegg Lars.',
#  " Vader leads a squadron of TIE fighters and prepares to attack Luke's X-wing "
#  'fighter, but Han returns and fires on the Imperials, sending Vader spiraling '
#  'away.',
#  ' While Obi-Wan goes to disable the tractor beam, Luke discovers that Leia is '
#  'imprisoned aboard, and with the help of Han and Chewbacca, rescues her.',
#  " While cleaning R2-D2, Luke accidentally triggers part of Leia's message, in "
#  'which she requests help from Obi-Wan Kenobi.',
#  ' While initially excited, Anakin begins to have prophetic visions of Padmé '
#  'dying in childbirth, and his worry steadily grows.',
#  ' With knowledge of the droid army, Supreme Chancellor Palpatine is voted '
#  'emergency powers to send the clones into battle.',
#  "Obi-Wan views Leia's complete message, in which she begs him to take the "
#  'Death Star plans to her home planet of Alderaan and give them to her father '
#  'for analysis.',
#  "Obi-Wan's investigation leads him to the remote ocean planet Kamino, where "
#  'he discovers an army of clones is being produced for the Republic, with '
#  'bounty hunter Jango Fett serving as their genetic template.',
#  'On Geonosis, Obi-Wan discovers a Separatist gathering led by Count Dooku, '
#  "whom Obi-Wan learns had authorized Padmé's assassination and is developing a "
#  'battle droid army with Trade Federation Viceroy Nute Gunray.',
#  'On Naboo, Padmé reveals herself to the Gungans as Queen Amidala and '
#  'persuades them into an alliance against the Trade Federation.',
#  "Ten years after the Trade Federation's invasion of Naboo, the Galactic "
#  'Republic is threatened by a Separatist movement organized by former Jedi '
#  'Master Count Dooku.',
#  "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust "
#  "port that connects to the station's main reactor.",
#  'The droids are captured by Jawa traders, who sell them to moisture farmers '
#  'Owen and Beru Lars and their nephew Luke Skywalker.',
#  'Three years after the destruction of the Death Star, the Rebel Alliance has '
#  'been driven from their former base on Yavin IV by the Galactic Empire.',
#  'Three years after the the start of the Clone Wars between the Galactic '
#  'Republic and the Confederacy of Independent Systems, war has gripped the '
#  'galaxy.',
#  "Upon the Falcon's arrival at the location of Alderaan, the group discover "
#  "that the planet has been destroyed by order of the Death Star's commanding "
#  'officer, Grand Moff Tarkin, as a show of power.'}
# ```

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**:
#
# > #how<br/>
# > #who<br/>
# > #fact-check<br/>
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**:
#
# > #how<br/>
# > how did Anakin become Darth Vader?<br/>
# > how did Anakin's mom die?<br/>
# > how did Anakin turn to the dark side?<br/>
# > how was Luke born?<br/>
# > how did Luke and Leia meet?<br/>
#
#
#
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "bookworm")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: bookworm (498c5a55-f3cb-4556-a268-146839c95982)
# {
#   "metadata": null,
#   "updated": "2017-09-24T14:12:09.495Z",
#   "learning_opt_out": false,
#   "workspace_id": "498c5a55-f3cb-4556-a268-146839c95982",
#   "name": "bookworm",
#   "created": "2017-09-23T22:57:19.966Z",
#   "language": "en",
#   "description": "I know a lot of stories. As me a question!",
#   "status": "Available"
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'Country', 'values': [{'value': 'Naboo'}]},
#  {'entity': 'Person',
#   'values': [{'value': 'Darth Maul'},
#    {'value': 'Darth Vader'},
#    {'value': 'Supreme Chancellor Palpatine'},
#    {'value': 'Cliegg Lars'},
#    {'value': 'Anakin Skywalker'},
#    {'value': 'Palpatine'},
#    {'value': 'Zam Wesell'},
#    {'value': 'Geonosis'},
#    {'value': 'Vader'},
#    {'value': 'Jango Fett'},
#    {'value': 'Luke'},
#    {'value': 'Luke Skywalker'},
#    {'value': 'Padmé Amidala'},
#    {'value': 'Boba'},
#    {'value': 'Queen Amidala'},
#    {'value': 'Viceroy Nute Gunray'},
#    {'value': 'Shmi'},
#    {'value': 'Gunray'},
#    {'value': 'Darth Sidious'},
#    {'value': 'Senator Padmé Amidala'},
#    {'value': 'Obi-Wan'},
#    {'value': 'Beru Lars'},
#    {'value': 'Han'},
#    {'value': 'Mace Windu'},
#    {'value': 'Count Dooku'},
#    {'value': 'Padmé'},
#    {'value': 'Princess Leia'},
#    {'value': 'Anakin'},
#    {'value': 'Obi-Wan Kenobi'},
#    {'value': 'Wookiee'},
#    {'value': 'Leia'}]},
#  {'entity': 'Quantity',
#   'values': [{'value': 'Ten years'}, {'value': 'Three years'}]},
#  {'entity': 'JobTitle',
#   'values': [{'value': 'Chancellor'},
#    {'value': 'commander'},
#    {'value': 'officer'}]},
#  {'entity': 'Facility',
#   'values': [{'value': 'Grand Moff Tarkin'}, {'value': 'Galactic Empire'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'Rebel Alliance'},
#    {'value': 'Confederacy of Independent Systems'},
#    {'value': 'Rebels'},
#    {'value': 'Tusken Raiders'},
#    {'value': 'Rebel assault squadron'},
#    {'value': 'droid army'},
#    {'value': 'Jedi Council'},
#    {'value': 'Galactic Republic'},
#    {'value': 'Trade Federation'}]},
#  {'entity': 'City',
#   'values': [{'value': 'Padmé'},
#    {'value': 'Theed'},
#    {'value': 'Geonosis'},
#    {'value': 'Gungans'},
#    {'value': 'Alderaan'},
#    {'value': 'Tusken'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'Falcon'}, {'value': 'Jawa traders'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "entity": "Country",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Naboo"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "JobTitle",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Chancellor"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "commander"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "officer"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "Person",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Darth Maul"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Darth Vader"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Supreme Chancellor Palpatine"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Cliegg Lars"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Anakin Skywalker"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Palpatine"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Zam Wesell"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Geonosis"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Vader"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Jango Fett"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Luke"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Luke Skywalker"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Padm\u00e9 Amidala"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Boba"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Queen Amidala"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Viceroy Nute Gunray"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Shmi"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Gunray"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Darth Sidious"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Senator Padm\u00e9 Amidala"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Obi-Wan"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Beru Lars"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Han"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Mace Windu"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Count Dooku"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Padm\u00e9"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Princess Leia"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Anakin"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Obi-Wan Kenobi"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Wookiee"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Leia"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "City",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Padm\u00e9"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Theed"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Geonosis"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Gungans"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Alderaan"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Tusken"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "Facility",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Grand Moff Tarkin"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Galactic Empire"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "Organization",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Rebel Alliance"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Confederacy of Independent Systems"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Rebels"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Tusken Raiders"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Rebel assault squadron"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "droid army"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Jedi Council"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Galactic Republic"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Trade Federation"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "Company",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Falcon"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Jawa traders"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   },
#   {
#     "entity": "Quantity",
#     "open_list": null,
#     "type": null,
#     "values": [
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Ten years"
#       },
#       {
#         "metadata": null,
#         "updated": "2017-09-24T14:26:03.071Z",
#         "type": "synonyms",
#         "synonyms": [],
#         "created": "2017-09-24T14:26:03.071Z",
#         "value": "Three years"
#       }
#     ],
#     "updated": "2017-09-24T14:26:03.071Z",
#     "source": null,
#     "description": null,
#     "created": "2017-09-24T14:26:03.071Z"
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**:
#
# > entity type: Facility, example: Grand Moff Tarkin<br/>
# > entity type: Person, example: Darth Vader<br/>
# > entity type: Country, example: Naboo

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**:
#
# > 1. Who: intent - #who
# > 2. How: intent - #how
# > 3. Person: entity - @Person

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's father?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "entity": "Person",
#       "confidence": 1,
#       "value": "Luke",
#       "location": [
#         7,
#         11
#       ]
#     },
#     {
#       "entity": "FamilyRelation",
#       "confidence": 1,
#       "value": "father",
#       "location": [
#         14,
#         20
#       ]
#     }
#   ],
#   "input": {
#     "text": "Who is Luke's father?",
#     "context": {
#       "conversation_id": "d5e0357c-0a0f-4a9d-bafe-1d4bbeb3e4c3",
#       "system": {
#         "dialog_turn_counter": 1,
#         "branch_exited_reason": "completed",
#         "branch_exited": true,
#         "dialog_request_counter": 1,
#         "_node_output_map": {
#           "Welcome": [
#             0
#           ]
#         },
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ]
#       }
#     }
#   },
#   "output": {
#     "text": [
#       "let me figure that out"
#     ],
#     "nodes_visited": [
#       "node_2_1506263481931"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "system": {
#       "dialog_turn_counter": 1,
#       "branch_exited_reason": "completed",
#       "branch_exited": true,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "node_3_1506265355471": [
#           0
#         ]
#       },
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ]
#     },
#     "conversation_id": "f11d6c45-be8c-490c-abff-6a02a2f97db3"
#   },
#   "intents": [
#     {
#       "confidence": 0.8153539657592774,
#       "intent": "who"
#     }
#   ]
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service
results = conversation.message(workspace_id=wrk_id, message_input={
    'text': 'who\'s Leia?'
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "entities": [
#     {
#       "entity": "Person",
#       "confidence": 1,
#       "value": "Leia",
#       "location": [
#         6,
#         10
#       ]
#     }
#   ],
#   "input": {
#     "text": "who's Leia?"
#   },
#   "output": {
#     "text": [
#       "let me figure that out"
#     ],
#     "nodes_visited": [
#       "node_2_1506263481931"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "system": {
#       "dialog_turn_counter": 1,
#       "branch_exited_reason": "completed",
#       "branch_exited": true,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "node_3_1506265355471": [
#           0
#         ]
#       },
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ]
#     },
#     "conversation_id": "ccd985d8-aa65-4d1d-b56a-7ea61d3dcbb2"
#   },
#   "intents": [
#     {
#       "confidence": 0.8762180805206299,
#       "intent": "who"
#     }
#   ]
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"] for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
# Out:
# Intent(s): ['who']
# Entities: ['Leia']

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "text:{}".format(",".join("\"{}\"".format(e) for e in query_entities)),
        "return": "text"
    })
print(json.dumps(query_results, indent=2))

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**:
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
